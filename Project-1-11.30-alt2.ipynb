# %%
#Defendencies
import pandas as pd
from pathlib import Path
import requests
import json
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# %%
#Use Panda to read Data
crash_data = pd.read_csv("Resources/Crash_Data.csv")
crash_data.head()
# Out:
#            X         Y  OBJECTID  Incidentid                DateTime  Year  \
# 0 -111.95221  33.42191         1     2598369  2012/01/01 07:25:00+00  2012
# 1 -111.93769  33.42319         2     2593420  2012/01/01 11:45:00+00  2012
# 2 -111.89196  33.41842         3     2588493  2012/01/01 18:07:00+00  2012
# 3 -111.94791  33.41779         4     2584449  2012/01/02 00:03:00+00  2012
# 4 -111.92847  33.34956         5     2592211  2012/01/02 00:12:00+00  2012
#
#       StreetName CrossStreet  Distance                      JunctionRelation  \
# 0  University Dr    Hardy Dr     0.000          Intersection Non Interchange
# 1         7th St  Myrtle Ave   139.920                  Not Junction Related
# 2       Price Rd   Orange St     0.000              Intersection Interchange
# 3        11th St     Judd St   200.112                  Not Junction Related
# 4       Rural Rd   Elliot Rd   135.168  Intersection Related Non Interchange
#
#    ...  Unittype_Two  Age_Drv2 Gender_Drv2 Traveldirection_Two  \
# 0  ...        Driver      20.0      Female                East
# 1  ...           NaN       NaN         NaN                 NaN
# 2  ...        Driver      31.0        Male               South
# 3  ...    Driverless       NaN         NaN                East
# 4  ...        Driver      20.0      Female               South
#
#          Unitaction_Two     Violation1_Drv2        AlcoholUse_Drv2  \
# 0  Going Straight Ahead  No Improper Action  No Apparent Influence
# 1                   NaN                 NaN                    NaN
# 2  Going Straight Ahead  No Improper Action  No Apparent Influence
# 3       Properly Parked                 NaN                    NaN
# 4  Going Straight Ahead  No Improper Action  No Apparent Influence
#
#             DrugUse_Drv2  Latitude  Longitude
# 0  No Apparent Influence  33.42191 -111.95221
# 1                    NaN  33.42319 -111.93769
# 2  No Apparent Influence  33.41842 -111.89196
# 3                    NaN  33.41779 -111.94791
# 4  No Apparent Influence  33.34956 -111.92847
#
# [5 rows x 35 columns]

# %%
crash_data.shape
# Out:
# (48882, 35)

# %%
crash_data.isna().sum()
# Out:
# X                       139
# Y                       139
# OBJECTID                  0
# Incidentid                0
# DateTime                  0
# Year                      0
# StreetName               19
# CrossStreet             304
# Distance                  1
# JunctionRelation          1
# Totalinjuries             1
# Totalfatalities           1
# Injuryseverity            1
# Collisionmanner           1
# Lightcondition            1
# Weather                   1
# SurfaceCondition          1
# Unittype_One              1
# Age_Drv1                 45
# Gender_Drv1             885
# Traveldirection_One       1
# Unitaction_One            1
# Violation1_Drv1          45
# AlcoholUse_Drv1          45
# DrugUse_Drv1             45
# Unittype_Two           3203
# Age_Drv2               4507
# Gender_Drv2            4604
# Traveldirection_Two    3203
# Unitaction_Two         3203
# Violation1_Drv2        4507
# AlcoholUse_Drv2        4507
# DrugUse_Drv2           4507
# Latitude                139
# Longitude               139
# dtype: int64

# %%
#filter Data to specific years
specific_year=crash_data.loc[(crash_data["Year"]==2020) | (crash_data["Year"]==2021)
                            | (crash_data["Year"]==2022)]
specific_year
# Out:
#                 X          Y  OBJECTID  Incidentid                DateTime  \
# 37637 -111.942400  33.422150     37638     3614716  2020/01/01 09:02:00+00
# 37638 -111.955590  33.407410     37639     3614159  2020/01/01 09:11:00+00
# 37639 -111.945770  33.424320     37640     3608918  2020/01/01 09:41:00+00
# 37640 -111.922400  33.414770     37641     3614004  2020/01/01 11:04:00+00
# 37641 -111.926260  33.434030     37642     3614179  2020/01/01 21:37:00+00
# ...           ...        ...       ...         ...                     ...
# 46462 -111.933653  33.421967     46463     4016095  2022/12/31 20:35:00+00
# 46463 -111.939610  33.393137     46464     4017552  2022/12/31 21:55:00+00
# 46464 -111.961130  33.378244     46465     4014475  2023/01/01 01:02:00+00
# 46465 -111.965455  33.378270     46466     4014901  2023/01/01 01:45:00+00
# 46466 -111.929306  33.436598     46467     4064275  2023/01/01 05:15:00+00
#
#        Year       StreetName          CrossStreet  Distance  \
# 37637  2020          Ash Ave        University Dr      80.0
# 37638  2020      Broadway Rd  Industrial Park Ave     -96.0
# 37639  2020        Wilson St               6th St       0.0
# 37640  2020      Apache Blvd           Terrace Rd    -600.0
# 37641  2020    Scottsdale Rd   Playa Del Norte Dr       0.0
# ...     ...              ...                  ...       ...
# 46462  2022    University Dr          College Ave     401.0
# 46463  2022         Mill Ave         Southern Ave     100.0
# 46464  2022      Baseline Rd            Darrow Dr       0.0
# 46465  2022  Arizona Mills S          Baseline Rd       0.0
# 46466  2022       Gilbert Dr          College Ave     230.0
#
#                JunctionRelation  ...  Unittype_Two  Age_Drv2 Gender_Drv2  \
# 37637  Intersection Related 206  ...        Driver      28.0        Male
# 37638      Not Junction Related  ...           NaN       NaN         NaN
# 37639    Intersection 4 Way 202  ...        Driver      61.0        Male
# 37640      Not Junction Related  ...        Driver      42.0        Male
# 37641  Intersection T Inter 203  ...        Driver      52.0      Female
# ...                         ...  ...           ...       ...         ...
# 46462      Not Junction Related  ...        Driver      22.0      Female
# 46463         Driveway Or Alley  ...        Driver      46.0      Female
# 46464    Intersection 4 Way 202  ...        Driver      19.0        Male
# 46465    Intersection 4 Way 202  ...        Driver      21.0        Male
# 46466      Not Junction Related  ...           NaN       NaN         NaN
#
#       Traveldirection_Two         Unitaction_Two     Violation1_Drv2  \
# 37637               South  Stopped In Trafficway  No Improper Action
# 37638                 NaN                    NaN                 NaN
# 37639               South   Going Straight Ahead  No Improper Action
# 37640                East   Going Straight Ahead  No Improper Action
# 37641                West       Making Left Turn  No Improper Action
# ...                   ...                    ...                 ...
# 46462                West  Stopped In Trafficway  No Improper Action
# 46463                East   Going Straight Ahead  No Improper Action
# 46464                West   Going Straight Ahead  No Improper Action
# 46465               South      Making Right Turn  No Improper Action
# 46466                 NaN                    NaN                 NaN
#
#              AlcoholUse_Drv2           DrugUse_Drv2   Latitude   Longitude
# 37637  No Apparent Influence  No Apparent Influence  33.422150 -111.942400
# 37638                    NaN                    NaN  33.407410 -111.955590
# 37639  No Apparent Influence  No Apparent Influence  33.424320 -111.945770
# 37640  No Apparent Influence  No Apparent Influence  33.414770 -111.922400
# 37641  No Apparent Influence  No Apparent Influence  33.434030 -111.926260
# ...                      ...                    ...        ...         ...
# 46462  No Apparent Influence  No Apparent Influence  33.421967 -111.933653
# 46463  No Apparent Influence  No Apparent Influence  33.393137 -111.939610
# 46464  No Apparent Influence  No Apparent Influence  33.378244 -111.961130
# 46465  No Apparent Influence  No Apparent Influence  33.378270 -111.965455
# 46466                    NaN                    NaN  33.436598 -111.929306
#
# [8830 rows x 35 columns]

# %%
specific_year.count()
# Out:
# X                      8829
# Y                      8829
# OBJECTID               8830
# Incidentid             8830
# DateTime               8830
# Year                   8830
# StreetName             8830
# CrossStreet            8665
# Distance               8829
# JunctionRelation       8829
# Totalinjuries          8829
# Totalfatalities        8829
# Injuryseverity         8829
# Collisionmanner        8829
# Lightcondition         8829
# Weather                8829
# SurfaceCondition       8829
# Unittype_One           8829
# Age_Drv1               8820
# Gender_Drv1            8614
# Traveldirection_One    8829
# Unitaction_One         8829
# Violation1_Drv1        8820
# AlcoholUse_Drv1        8820
# DrugUse_Drv1           8820
# Unittype_Two           8042
# Age_Drv2               7724
# Gender_Drv2            7705
# Traveldirection_Two    8042
# Unitaction_Two         8042
# Violation1_Drv2        7724
# AlcoholUse_Drv2        7724
# DrugUse_Drv2           7724
# Latitude               8829
# Longitude              8829
# dtype: int64

# %%
#drop null rows
Filter_data=specific_year.dropna(how='any')

# %%
Filter_data.count()
# Out:
# X                      7400
# Y                      7400
# OBJECTID               7400
# Incidentid             7400
# DateTime               7400
# Year                   7400
# StreetName             7400
# CrossStreet            7400
# Distance               7400
# JunctionRelation       7400
# Totalinjuries          7400
# Totalfatalities        7400
# Injuryseverity         7400
# Collisionmanner        7400
# Lightcondition         7400
# Weather                7400
# SurfaceCondition       7400
# Unittype_One           7400
# Age_Drv1               7400
# Gender_Drv1            7400
# Traveldirection_One    7400
# Unitaction_One         7400
# Violation1_Drv1        7400
# AlcoholUse_Drv1        7400
# DrugUse_Drv1           7400
# Unittype_Two           7400
# Age_Drv2               7400
# Gender_Drv2            7400
# Traveldirection_Two    7400
# Unitaction_Two         7400
# Violation1_Drv2        7400
# AlcoholUse_Drv2        7400
# DrugUse_Drv2           7400
# Latitude               7400
# Longitude              7400
# dtype: int64

# %%
Filter_data["Unittype_Two"].unique()
# Out:
# array(['Driver', 'Pedestrian', 'Pedalcyclist'], dtype=object)

# %%
#The people who use Automobile
group_data= Filter_data.groupby(["Unittype_Two"]).count()
filtered_data_df=group_data[["Incidentid"]]
filtered_data_df
# Out:
#               Incidentid
# Unittype_Two
# Driver              7179
# Pedalcyclist          88
# Pedestrian           133

# %%
# filtering data by crashes involved with drivers
Driver_accident=Filter_data.loc[Filter_data["Unittype_Two"]== "Driver", :]
Driver_accident
# Out:
#                 X          Y  OBJECTID  Incidentid                DateTime  \
# 37637 -111.942400  33.422150     37638     3614716  2020/01/01 09:02:00+00
# 37639 -111.945770  33.424320     37640     3608918  2020/01/01 09:41:00+00
# 37640 -111.922400  33.414770     37641     3614004  2020/01/01 11:04:00+00
# 37641 -111.926260  33.434030     37642     3614179  2020/01/01 21:37:00+00
# 37642 -111.890330  33.407480     37643     3614177  2020/01/01 23:45:00+00
# ...           ...        ...       ...         ...                     ...
# 46461 -111.965928  33.349081     46462     4017542  2022/12/31 15:47:00+00
# 46462 -111.933653  33.421967     46463     4016095  2022/12/31 20:35:00+00
# 46463 -111.939610  33.393137     46464     4017552  2022/12/31 21:55:00+00
# 46464 -111.961130  33.378244     46465     4014475  2023/01/01 01:02:00+00
# 46465 -111.965455  33.378270     46466     4014901  2023/01/01 01:45:00+00
#
#        Year       StreetName         CrossStreet  Distance  \
# 37637  2020          Ash Ave       University Dr      80.0
# 37639  2020        Wilson St              6th St       0.0
# 37640  2020      Apache Blvd          Terrace Rd    -600.0
# 37641  2020    Scottsdale Rd  Playa Del Norte Dr       0.0
# 37642  2020         Price Rd         Broadway Rd       0.0
# ...     ...              ...                 ...       ...
# 46461  2022        Elliot Rd            Harl Ave       0.0
# 46462  2022    University Dr         College Ave     401.0
# 46463  2022         Mill Ave        Southern Ave     100.0
# 46464  2022      Baseline Rd           Darrow Dr       0.0
# 46465  2022  Arizona Mills S         Baseline Rd       0.0
#
#                JunctionRelation  ...  Unittype_Two  Age_Drv2 Gender_Drv2  \
# 37637  Intersection Related 206  ...        Driver      28.0        Male
# 37639    Intersection 4 Way 202  ...        Driver      61.0        Male
# 37640      Not Junction Related  ...        Driver      42.0        Male
# 37641  Intersection T Inter 203  ...        Driver      52.0      Female
# 37642    Intersection 4 Way 202  ...        Driver      24.0        Male
# ...                         ...  ...           ...       ...         ...
# 46461    Intersection 4 Way 202  ...        Driver      50.0        Male
# 46462      Not Junction Related  ...        Driver      22.0      Female
# 46463         Driveway Or Alley  ...        Driver      46.0      Female
# 46464    Intersection 4 Way 202  ...        Driver      19.0        Male
# 46465    Intersection 4 Way 202  ...        Driver      21.0        Male
#
#       Traveldirection_Two         Unitaction_Two     Violation1_Drv2  \
# 37637               South  Stopped In Trafficway  No Improper Action
# 37639               South   Going Straight Ahead  No Improper Action
# 37640                East   Going Straight Ahead  No Improper Action
# 37641                West       Making Left Turn  No Improper Action
# 37642           Northwest       Making Left Turn  No Improper Action
# ...                   ...                    ...                 ...
# 46461                West   Going Straight Ahead  No Improper Action
# 46462                West  Stopped In Trafficway  No Improper Action
# 46463                East   Going Straight Ahead  No Improper Action
# 46464                West   Going Straight Ahead  No Improper Action
# 46465               South      Making Right Turn  No Improper Action
#
#              AlcoholUse_Drv2           DrugUse_Drv2   Latitude   Longitude
# 37637  No Apparent Influence  No Apparent Influence  33.422150 -111.942400
# 37639  No Apparent Influence  No Apparent Influence  33.424320 -111.945770
# 37640  No Apparent Influence  No Apparent Influence  33.414770 -111.922400
# 37641  No Apparent Influence  No Apparent Influence  33.434030 -111.926260
# 37642  No Apparent Influence  No Apparent Influence  33.407480 -111.890330
# ...                      ...                    ...        ...         ...
# 46461  No Apparent Influence  No Apparent Influence  33.349081 -111.965928
# 46462  No Apparent Influence  No Apparent Influence  33.421967 -111.933653
# 46463  No Apparent Influence  No Apparent Influence  33.393137 -111.939610
# 46464  No Apparent Influence  No Apparent Influence  33.378244 -111.961130
# 46465  No Apparent Influence  No Apparent Influence  33.378270 -111.965455
#
# [7179 rows x 35 columns]

# %%
# Create a high-level snapshot of the incident's information
Data_frame= Driver_accident[["Incidentid", "DateTime", "StreetName", "Totalinjuries", "Totalfatalities",
                             "Injuryseverity", "Lightcondition", "Weather", "SurfaceCondition", "Age_Drv2",
                             "Gender_Drv2", "Unitaction_Two", "Violation1_Drv2", "AlcoholUse_Drv2", 
                             "DrugUse_Drv2", "Latitude", "Longitude", "Year"
                            ]]
Data_frame
# Out:
#        Incidentid                DateTime       StreetName  Totalinjuries  \
# 37637     3614716  2020/01/01 09:02:00+00          Ash Ave            0.0
# 37639     3608918  2020/01/01 09:41:00+00        Wilson St            0.0
# 37640     3614004  2020/01/01 11:04:00+00      Apache Blvd            1.0
# 37641     3614179  2020/01/01 21:37:00+00    Scottsdale Rd            1.0
# 37642     3614177  2020/01/01 23:45:00+00         Price Rd            0.0
# ...           ...                     ...              ...            ...
# 46461     4017542  2022/12/31 15:47:00+00        Elliot Rd            0.0
# 46462     4016095  2022/12/31 20:35:00+00    University Dr            0.0
# 46463     4017552  2022/12/31 21:55:00+00         Mill Ave            0.0
# 46464     4014475  2023/01/01 01:02:00+00      Baseline Rd            1.0
# 46465     4014901  2023/01/01 01:45:00+00  Arizona Mills S            0.0
#
#        Totalfatalities          Injuryseverity    Lightcondition  Weather  \
# 37637              0.0               No Injury      Dark Lighted    Clear
# 37639              0.0               No Injury  Dark Not Lighted    Clear
# 37640              0.0  Suspected Minor Injury      Dark Lighted    Clear
# 37641              0.0         Possible Injury          Daylight    Clear
# 37642              0.0               No Injury          Daylight    Clear
# ...                ...                     ...               ...      ...
# 46461              0.0               No Injury        Unknown 51  Unknown
# 46462              0.0               No Injury          Daylight   Cloudy
# 46463              0.0               No Injury          Daylight    Clear
# 46464              0.0  Suspected Minor Injury      Dark Lighted   Cloudy
# 46465              0.0               No Injury      Dark Lighted   Cloudy
#
#       SurfaceCondition  Age_Drv2 Gender_Drv2         Unitaction_Two  \
# 37637              Dry      28.0        Male  Stopped In Trafficway
# 37639              Dry      61.0        Male   Going Straight Ahead
# 37640              Dry      42.0        Male   Going Straight Ahead
# 37641              Dry      52.0      Female       Making Left Turn
# 37642              Dry      24.0        Male       Making Left Turn
# ...                ...       ...         ...                    ...
# 46461              Dry      50.0        Male   Going Straight Ahead
# 46462              Dry      22.0      Female  Stopped In Trafficway
# 46463              Dry      46.0      Female   Going Straight Ahead
# 46464              Dry      19.0        Male   Going Straight Ahead
# 46465              Dry      21.0        Male      Making Right Turn
#
#           Violation1_Drv2        AlcoholUse_Drv2           DrugUse_Drv2  \
# 37637  No Improper Action  No Apparent Influence  No Apparent Influence
# 37639  No Improper Action  No Apparent Influence  No Apparent Influence
# 37640  No Improper Action  No Apparent Influence  No Apparent Influence
# 37641  No Improper Action  No Apparent Influence  No Apparent Influence
# 37642  No Improper Action  No Apparent Influence  No Apparent Influence
# ...                   ...                    ...                    ...
# 46461  No Improper Action  No Apparent Influence  No Apparent Influence
# 46462  No Improper Action  No Apparent Influence  No Apparent Influence
# 46463  No Improper Action  No Apparent Influence  No Apparent Influence
# 46464  No Improper Action  No Apparent Influence  No Apparent Influence
# 46465  No Improper Action  No Apparent Influence  No Apparent Influence
#
#         Latitude   Longitude  Year
# 37637  33.422150 -111.942400  2020
# 37639  33.424320 -111.945770  2020
# 37640  33.414770 -111.922400  2020
# 37641  33.434030 -111.926260  2020
# 37642  33.407480 -111.890330  2020
# ...          ...         ...   ...
# 46461  33.349081 -111.965928  2022
# 46462  33.421967 -111.933653  2022
# 46463  33.393137 -111.939610  2022
# 46464  33.378244 -111.961130  2022
# 46465  33.378270 -111.965455  2022
#
# [7179 rows x 18 columns]

# %%
#rename columns
new_data_df=Data_frame.rename(columns={"Age_Drv2": "Age",
                                        "Gender_Drv2": "Gender",
                                        "Unitaction_Two": "Unitaction",
                                        "Violation1_Drv2": "Violation",
                                        "AlcoholUse_Drv2": "AlcoholUse",
                                        "DrugUse_Drv2": "DrugUse",
                                        "DrugUse_Drv2": "DrugUse",
                                        "Totalinjuries": "Total injuries",
                                        "Totalfatalities" : "Total fatalities"
                                        })
new_data_df
# Out:
#        Incidentid                DateTime       StreetName  Total injuries  \
# 37637     3614716  2020/01/01 09:02:00+00          Ash Ave             0.0
# 37639     3608918  2020/01/01 09:41:00+00        Wilson St             0.0
# 37640     3614004  2020/01/01 11:04:00+00      Apache Blvd             1.0
# 37641     3614179  2020/01/01 21:37:00+00    Scottsdale Rd             1.0
# 37642     3614177  2020/01/01 23:45:00+00         Price Rd             0.0
# ...           ...                     ...              ...             ...
# 46461     4017542  2022/12/31 15:47:00+00        Elliot Rd             0.0
# 46462     4016095  2022/12/31 20:35:00+00    University Dr             0.0
# 46463     4017552  2022/12/31 21:55:00+00         Mill Ave             0.0
# 46464     4014475  2023/01/01 01:02:00+00      Baseline Rd             1.0
# 46465     4014901  2023/01/01 01:45:00+00  Arizona Mills S             0.0
#
#        Total fatalities          Injuryseverity    Lightcondition  Weather  \
# 37637               0.0               No Injury      Dark Lighted    Clear
# 37639               0.0               No Injury  Dark Not Lighted    Clear
# 37640               0.0  Suspected Minor Injury      Dark Lighted    Clear
# 37641               0.0         Possible Injury          Daylight    Clear
# 37642               0.0               No Injury          Daylight    Clear
# ...                 ...                     ...               ...      ...
# 46461               0.0               No Injury        Unknown 51  Unknown
# 46462               0.0               No Injury          Daylight   Cloudy
# 46463               0.0               No Injury          Daylight    Clear
# 46464               0.0  Suspected Minor Injury      Dark Lighted   Cloudy
# 46465               0.0               No Injury      Dark Lighted   Cloudy
#
#       SurfaceCondition   Age  Gender             Unitaction  \
# 37637              Dry  28.0    Male  Stopped In Trafficway
# 37639              Dry  61.0    Male   Going Straight Ahead
# 37640              Dry  42.0    Male   Going Straight Ahead
# 37641              Dry  52.0  Female       Making Left Turn
# 37642              Dry  24.0    Male       Making Left Turn
# ...                ...   ...     ...                    ...
# 46461              Dry  50.0    Male   Going Straight Ahead
# 46462              Dry  22.0  Female  Stopped In Trafficway
# 46463              Dry  46.0  Female   Going Straight Ahead
# 46464              Dry  19.0    Male   Going Straight Ahead
# 46465              Dry  21.0    Male      Making Right Turn
#
#                 Violation             AlcoholUse                DrugUse  \
# 37637  No Improper Action  No Apparent Influence  No Apparent Influence
# 37639  No Improper Action  No Apparent Influence  No Apparent Influence
# 37640  No Improper Action  No Apparent Influence  No Apparent Influence
# 37641  No Improper Action  No Apparent Influence  No Apparent Influence
# 37642  No Improper Action  No Apparent Influence  No Apparent Influence
# ...                   ...                    ...                    ...
# 46461  No Improper Action  No Apparent Influence  No Apparent Influence
# 46462  No Improper Action  No Apparent Influence  No Apparent Influence
# 46463  No Improper Action  No Apparent Influence  No Apparent Influence
# 46464  No Improper Action  No Apparent Influence  No Apparent Influence
# 46465  No Improper Action  No Apparent Influence  No Apparent Influence
#
#         Latitude   Longitude  Year
# 37637  33.422150 -111.942400  2020
# 37639  33.424320 -111.945770  2020
# 37640  33.414770 -111.922400  2020
# 37641  33.434030 -111.926260  2020
# 37642  33.407480 -111.890330  2020
# ...          ...         ...   ...
# 46461  33.349081 -111.965928  2022
# 46462  33.421967 -111.933653  2022
# 46463  33.393137 -111.939610  2022
# 46464  33.378244 -111.961130  2022
# 46465  33.378270 -111.965455  2022
#
# [7179 rows x 18 columns]

# %%
#count total injuries and fatalities
total_injuries=new_data_df.groupby(["Year"]).count()
total_injuries_df=total_injuries[["Total injuries", "Total fatalities"]]
total_injuries_df
# Out:
#       Total injuries  Total fatalities
# Year
# 2020            1896              1896
# 2021            2224              2224
# 2022            3059              3059

# %%
# Create bins for age groups
bins = [15, 25, 40, 60, 85]
labels = ['Age 15-24', 'Age 25-39', 'Age 40-59', 'Age 60-85']

# Create a new column 'AgeGroup' based on the bins
new_data_df['AgeGroup'] = pd.cut(new_data_df['Age'], bins=bins, labels=labels, right=False)

# Create a new column 'WeatherSurface' based on the combination of 'Weather' and 'SurfaceCondition'
new_data_df['WeatherSurface'] = new_data_df['Weather'] + ' ' + new_data_df['SurfaceCondition']

# Group by 'AgeGroup' and 'WeatherSurface', then count occurrences
age_and_weather_counts = new_data_df.groupby(['AgeGroup', 'WeatherSurface']).size().unstack()

# Rename the columns for clarity
age_and_weather_counts.columns = [f"{col} Count" for col in age_and_weather_counts.columns]

# Reset index for a cleaner DataFrame
age_and_weather_counts.reset_index(inplace=True)

# Display the result
age_and_weather_counts
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_27952\3259952404.py:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_and_weather_counts = new_data_df.groupby(['AgeGroup', 'WeatherSurface']).size().unstack()
#     AgeGroup  Blowing Sand Soil Dirt Dry Count  Clear Dry Count  \
# 0  Age 15-24                                 1             1684
# 1  Age 25-39                                 0             2098
# 2  Age 40-59                                 0             1602
# 3  Age 60-85                                 1              702
#
#    Clear Mud Dirt Gravel Count  Clear Snow Count  Clear Unknown Count  \
# 0                            1                 1                    9
# 1                            0                 0                   13
# 2                            1                 0                    9
# 3                            0                 0                   11
#
#    Clear Water Standing Moving Count  Clear Wet Count  Cloudy Dry Count  \
# 0                                  0                7               124
# 1                                  0                7               156
# 2                                  1                3               132
# 3                                  0                2                58
#
#    Cloudy Unknown Count  Cloudy Wet Count  Fog Smog Smoke Dry Count  \
# 0                     0                11                         1
# 1                     1                19                         2
# 2                     2                11                         0
# 3                     0                10                         0
#
#    Rain Dry Count  Rain Water Standing Moving Count  Rain Wet Count  \
# 0               7                                 0              38
# 1               6                                 0              35
# 2               2                                 1              31
# 3               3                                 0              13
#
#    Sleet Hail Freezing Rain Or Drizzle Dry Count  Unknown Dry Count  \
# 0                                              1                 39
# 1                                              0                 44
# 2                                              0                 38
# 3                                              0                 12
#
#    Unknown Mud Dirt Gravel Count  Unknown Unknown Count  Unknown Wet Count
# 0                              0                     20                  2
# 1                              0                     13                  0
# 2                              1                     12                  0
# 3                              0                      4                  0

# %%
# Select desired columns
final_filter_age_weather_data = age_and_weather_counts[["AgeGroup", "Clear Dry Count", 
                                 "Cloudy Dry Count",
                                 "Rain Wet Count"
                                ]]
# Rename columns
rename_age_and_weather_counts = final_filter_age_weather_data.rename(columns={
    "Clear Dry Count": "Clear weather with dry surface",
    "Cloudy Dry Count": "Cloudy weather with dry surface",
    "Rain Wet Count": "Rainy weather with wet surface",
})
rename_age_and_weather_counts
# Out:
#     AgeGroup  Clear weather with dry surface  Cloudy weather with dry surface  \
# 0  Age 15-24                            1684                              124
# 1  Age 25-39                            2098                              156
# 2  Age 40-59                            1602                              132
# 3  Age 60-85                             702                               58
#
#    Rainy weather with wet surface
# 0                              38
# 1                              35
# 2                              31
# 3                              13

# %%
#Generate a bar plot showing the total number of people per road condition.
Figure1=rename_age_and_weather_counts.plot(kind="bar", xlabel="Age", ylabel="Number of Incidents")
xticklabels=age_and_weather_counts["AgeGroup"].unique()
Figure1.set_xticklabels(xticklabels, rotation=90)
plt.title("Total Number of People per Road Condition")
Figure1
# Out:
# <Axes: title={'center': 'Total Number of People per Road Condition'}, xlabel='Age', ylabel='Number of Incidents'>

# %%
print("Q1=Is there a correlation between age and road conditions that cause automobile accidents in City of Tempe during the year 2020-2022?")
print("Answer:  ")
# Out:
# Q1=Is there a correlation between age and road conditions that cause automobile accidents in City of Tempe during the year 2020-2022?
# Answer:

# %%
#question2: find people who use alcohol
Driver_accident["AlcoholUse_Drv2"].unique()
# Out:
# array(['No Apparent Influence', 'Alcohol'], dtype=object)

# %%
#filter data who use alcohol
cause_accident=new_data_df.loc[(new_data_df["AlcoholUse"]== "Alcohol")                        ]
specific_coloumn=cause_accident[["Incidentid",
                                "AlcoholUse", "Gender"
                                ]]
specific_coloumn
# Out:
#        Incidentid AlcoholUse  Gender
# 37908     3629760    Alcohol    Male
# 38807     3666774    Alcohol    Male
# 38843     3667268    Alcohol    Male
# 38882     3663894    Alcohol    Male
# 39302     3688872    Alcohol    Male
# 39518     3703041    Alcohol    Male
# 39699     3716882    Alcohol  Female
# 40894     3778434    Alcohol    Male
# 41999     3837376    Alcohol    Male
# 42258     3849084    Alcohol    Male
# 42662     3911349    Alcohol  Female
# 42684     3920632    Alcohol  Female
# 42983     3869762    Alcohol  Female
# 43122     3927560    Alcohol  Female
# 43233     3932076    Alcohol  Female
# 43352     3879789    Alcohol    Male
# 43561     3934765    Alcohol    Male
# 43562     3935832    Alcohol  Female
# 43604     3937792    Alcohol  Female
# 43627     3935823    Alcohol    Male
# 43914     3935863    Alcohol    Male
# 43922     3946006    Alcohol  Female
# 44032     3954311    Alcohol  Female
# 44176     3945301    Alcohol    Male
# 44319     3969129    Alcohol    Male
# 44889     3969741    Alcohol    Male
# 45560     4009030    Alcohol  Female
# 46383     4017392    Alcohol    Male

# %%
alcohol_accident=specific_coloumn.groupby("Gender").count()
alcohol_accident
# Out:
#         Incidentid  AlcoholUse
# Gender
# Female          11          11
# Male            17          17

# %%
# Generate a pie plot showing the distribution of people who use alcohol
labels=["Femail", "Male"]
alcohol_accident = specific_coloumn.groupby("Gender")["AlcoholUse"].count()
plt.pie(alcohol_accident, autopct='%2.2f%%', labels=labels)
plt.title("Distribution of people who use alcohol")
plt.show()
